# %%
import pandas as pd
import numpy as np
import os
import pyodbc
import datetime

# %%
os.chdir('C:\\Users\\hp\\Desktop\\ProFinch')

# %%
df=pd.read_excel("CustomerInfo5.xlsx")

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'gender', 'age', 'country', 'state',
#        'postal code', 'social security number', 'company', 'job title',
#        'salary', 'card number', 'card type', 'money_withdrawn_amount',
#        'money_withdrawn_reason', 'money_withdrawn_location',
#        'Suspicious Activity', 'No.of Transactions', 'money_withdrawn_date',
#        'money_withdrawn_date_only', 'amount_transferred', 'sender_id',
#        'receiver_id', 'Time_only'],
#       dtype='object')

# %%
df.to_csv('CustomerDataNew.csv')

# %%
df=df.fillna(0)

# %%
df
# Out:
#      first_name  last_name  gender  age        country                 state  \
# 0         Aaron    Skirrow    Male   73  United States            Washington
# 1          Abbe   Kauscher  Female   89  United States              Missouri
# 2         Abram     Vinton    Male   33  United States                  Iowa
# 3      Adelheid  Gainforth  Female   61  United States                 Texas
# 4      Adelheid     Sackur  Female   76  United States              Missouri
# ...         ...        ...     ...  ...            ...                   ...
# 997    Zaccaria       Thow    Male   72  United States                 Texas
# 998         Zak     Shimon    Male   25  United States            California
# 999     Zebedee     Hartup    Male   52  United States              New York
# 1000      Zenia   Patience  Female   22  United States  District of Columbia
# 1001      Zorah       Pill  Female   23  United States  District of Columbia
#
#       postal code social security number      company  \
# 0           98140            857-26-6919        InnoZ
# 1           65810            209-26-1487     Livetube
# 2           50369            406-67-0764       Leenti
# 3           77388            224-56-1586      Blogtag
# 4           64142            749-34-4385       Camido
# ...           ...                    ...          ...
# 997         88574            692-56-8900         Katz
# 998         92105            545-47-9553        Quatz
# 999         11241            415-93-7210         Eare
# 1000        20535            415-21-2084  Shufflebeat
# 1001        20508            673-78-2460         Ntag
#
#                          job title  ...  money_withdrawn_reason  \
# 0               Nurse Practicioner  ...             Electronics
# 1                 Web Designer III  ...                    Toys
# 2       Quality Control Specialist  ...                   Tools
# 3          GIS Technical Architect  ...                   Music
# 4     Structural Analysis Engineer  ...              Automotive
# ...                            ...  ...                     ...
# 997           Software Engineer IV  ...                  Movies
# 998            Executive Secretary  ...                   Tools
# 999                  Geologist III  ...                   Shoes
# 1000             Director of Sales  ...                  Health
# 1001       Human Resources Manager  ...                   Shoes
#
#       money_withdrawn_location Suspicious Activity  No.of Transactions  \
# 0                   Washington               False                   1
# 1                         Ohio                True                   1
# 2                         Iowa               False                   1
# 3                        Texas                True                   1
# 4                 Pennsylvania                True                   1
# ...                        ...                 ...                 ...
# 997                      Texas               False                   1
# 998                 California               False                   1
# 999                   New York               False                   1
# 1000      District of Columbia               False                   1
# 1001      District of Columbia               False                   1
#
#      money_withdrawn_date money_withdrawn_date_only  amount_transferred  \
# 0     2017-01-23 05:32:04                  01/23/17             8320.42
# 1     2017-02-13 04:09:48                  02/13/17            10615.00
# 2     2017-04-04 11:14:20                  04/04/17            24223.40
# 3     2018-01-23 03:52:32                  01/23/18             9866.93
# 4     2019-01-01 06:19:38                  01/01/19            16041.25
# ...                   ...                       ...                 ...
# 997   2018-10-04 05:45:45                  10/04/18            11396.52
# 998   2019-01-24 06:43:38                  01/24/19            16449.56
# 999   2017-10-21 16:58:33                  10/21/17             3125.18
# 1000  2018-06-19 00:55:45                  06/19/18            18477.26
# 1001  2018-10-28 20:04:12                  10/28/18              859.61
#
#       sender_id receiver_id Time_only
# 0           725        1725  05:32:04
# 1           673        1673  04:09:48
# 2           610        1610  11:14:20
# 3           455        1455  03:52:32
# 4           186        1186  06:19:38
# ...         ...         ...       ...
# 997          30        1030  05:45:45
# 998         653        1653  06:43:38
# 999          83        1083  16:58:33
# 1000         20        1020  00:55:45
# 1001        508        1508  20:04:12
#
# [1002 rows x 24 columns]
