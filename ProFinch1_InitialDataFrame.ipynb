# %%
import pandas as pd
import numpy as np
import os
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from matplotlib import cm
from sklearn import metrics
from sklearn import ensemble
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn import datasets, linear_model, metrics
import math

# %%
pwd
# Out:
# 'C:\\Users\\hp\\ProFinch'

# %%
os.chdir('C:\\Users\\hp\\Desktop\\ProFinch')

# %%
os.listdir()
# Out:
# ['BlockDiagram.png',
#  'CustomerData.xlsx',
#  'CustomerInfo.xlsx',
#  'CustomerInfo2.xlsx',
#  'CustomerInfo3.xlsx',
#  'Features List.docx',
#  'Internship_Krishnakanth.doc',
#  'Possible Rules.docx',
#  'Rules.txt']

# %%
df=pd.DataFrame()
df=pd.read_excel("CustomerInfo5.xlsx")

# %%
df.describe()
# Out:
#         Unnamed: 0          age   postal code         salary   card number  \
# count  1002.000000  1002.000000   1002.000000    1002.000000  1.002000e+03
# mean    500.500000    54.644711  54442.656687   87154.070858  2.837566e+17
# std     289.396786    20.902120  28436.678654   36291.820099  1.190323e+18
# min       0.000000    19.000000   1114.000000   12000.000000  4.017950e+12
# 25%     250.250000    36.250000  32144.500000   56853.250000  3.541871e+15
# 50%     500.500000    55.000000  55422.500000   87930.000000  3.578774e+15
# 75%     750.750000    72.000000  79871.000000  119453.500000  5.520951e+15
# max    1001.000000    90.000000  99512.000000  149963.000000  6.771504e+18
#
#        money_withdrawn_amount  No.of Transactions  amount_transferred  \
# count             1002.000000              1002.0         1002.000000
# mean             15055.631627                 1.0        12584.232964
# std               8661.047767                 0.0         7175.751273
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 first_name  last_name  gender  age        country       state  \
# 0           0      Aaron    Skirrow    Male   73  United States  Washington
# 1           1       Abbe   Kauscher  Female   89  United States    Missouri
# 2           2      Abram     Vinton    Male   33  United States        Iowa
# 3           3   Adelheid  Gainforth  Female   61  United States       Texas
# 4           4   Adelheid     Sackur  Female   76  United States    Missouri
#
#    postal code social security number   company  ... money_withdrawn_reason  \
# 0        98140            857-26-6919     InnoZ  ...            Electronics
# 1        65810            209-26-1487  Livetube  ...                   Toys
# 2        50369            406-67-0764    Leenti  ...                  Tools
# 3        77388            224-56-1586   Blogtag  ...                  Music
# 4        64142            749-34-4385    Camido  ...             Automotive
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'first_name',
#  'last_name',
#  'gender',
#  'age',
#  'country',
#  'state',
#  'postal code',
#  'social security number',
#  'company',
#  'job title',
#  'salary',
#  'card number',
#  'card type',
#  'money_withdrawn_amount',
#  'money_withdrawn_reason',
#  'money_withdrawn_location',
#  'Suspicious Activity',
#  'No.of Transactions',
#  'money_withdrawn_date',
#  'money_withdrawn_date_only',
#  'amount_transferred',
#  'sender_id',
#  'receiver_id',
#  'Time_only']

# %% [markdown]
# # Deleting unwanted columns and adding datetime column

# %%
df=df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1','Valid Transaction','money_withdrawn_time'])

# %%
df.columns.tolist()
# Out:
# ['first_name',
#  'last_name',
#  'gender',
#  'age',
#  'country',
#  'state',
#  'postal code',
#  'social security number',
#  'company',
#  'job title',
#  'salary',
#  'card number',
#  'card type',
#  'money_withdrawn_amount',
#  'money_withdrawn_reason',
#  'money_withdrawn_location',
#  'Suspicious Activity',
#  'No.of Transactions']

# %%
df['money_withdrawn_date']=""

# %%
import datetime
df2=pd.DataFrame()
df2['Datee']=""

# %%
for i in range(10):
    df2.loc[i,'Datee']=list1[i]

# %%
df2
# Out:
#                  Datee
# 0  2016-06-18 08:14:51
# 1  2016-05-10 19:33:46
# 2  2016-04-22 04:36:21
# 3  2016-06-19 11:18:54
# 4  2016-08-07 03:23:44
# 5  2017-04-07 15:02:53
# 6  2015-12-18 18:03:07
# 7  2016-03-30 09:37:33
# 8  2015-05-20 12:15:24
# 9  2016-03-23 13:25:16

# %%
df2.loc[10,'Datee']=pd.Timestamp(2017, 1, 1, 14, 30, 15)

# %%
df2
# Out:
#                   Datee
# 0   2016-06-18 08:14:51
# 1   2016-05-10 19:33:46
# 2   2016-04-22 04:36:21
# 3   2016-06-19 11:18:54
# 4   2016-08-07 03:23:44
# 5   2017-04-07 15:02:53
# 6   2015-12-18 18:03:07
# 7   2016-03-30 09:37:33
# 8   2015-05-20 12:15:24
# 9   2016-03-23 13:25:16
# 10  2017-01-01 14:30:15

# %%
def random_dates(start, end, n=1000):

    start_u = start.value//10**9
    end_u = end.value//10**9

    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
start = pd.to_datetime('2017-01-01')
end = pd.to_datetime('2019-12-31')
list1=random_dates(start, end)

# %%
for i in range(1000):
    df.loc[i,'money_withdrawn_date']=list1[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ef32e052b1d2> in <module>
#       1 for i in range(1000):
# ----> 2     df.loc[i,'money_withdrawn_date']=list1[i]
#
# NameError: name 'df' is not defined

# %%
df['money_withdrawn_date']
# Out:
# 0     2017-02-15 07:41:11
# 1     2017-09-25 11:49:52
# 2     2018-05-03 07:49:19
# 3     2019-06-07 03:04:05
# 4     2019-09-28 22:04:18
#               ...
# 995   2019-06-25 20:36:21
# 996   2018-03-16 00:15:30
# 997   2018-07-13 22:16:46
# 998   2017-10-26 01:44:52
# 999   2018-03-27 09:52:30
# Name: money_withdrawn_date, Length: 1000, dtype: datetime64[ns]

# %%
df['money_withdrawn_date_only']=""

# %%
for i in range(1000):
    df['money_withdrawn_date_only'][i]=df['money_withdrawn_date'][i].strftime("%x")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
(df['money_withdrawn_date_only'][0])
# Out:
# '02/15/17'

# %%
(df['money_withdrawn_date'][0])
# Out:
# Timestamp('2017-02-15 07:41:11')

# %%
list1[0].strftime("%x")
# Out:
# '02/15/17'

# %%
df.to_excel("CustomerInfo4.xlsx")

# %% [markdown]
# # End of section

# %%
df['Fradulent']=True

# %%
import numpy as np
values=np.random.choice(range(1000), 200, replace=False)

# %%
values
# Out:
# array([693, 939, 126, 832, 636, 691, 802, 239, 209, 107, 698, 260, 341,
#        813,  54, 178, 315, 788, 440,   7, 978, 197, 186, 752, 292, 286,
#        914,  93,  65,   1,  87, 476, 340, 327, 404, 943, 637, 448, 522,
#        132, 299, 975, 735, 291, 563, 250, 823, 699, 242,  84, 740, 388,
#         36, 704, 682, 614, 883, 155, 449, 988, 297, 413, 311, 535, 205,
#        763, 330, 113, 201, 510, 612, 303, 457, 574, 227,  32, 770, 888,
#        688,  60,  29, 818,  61,  56,  15, 617, 381, 268, 208, 281, 684,
#        953, 367, 435, 846, 645, 442, 369, 821, 159, 233, 998, 976, 212,
#        642, 940, 797,  50, 429, 398, 661, 670, 530, 558, 907, 454, 325,
#        860, 517, 653, 608, 747, 807,  23, 245, 444, 115, 182, 490, 409,
#        849, 406,  75, 507, 948, 647, 901, 651, 371, 273, 180, 954, 592,
#        417, 935, 540, 363, 464,  83, 996, 663, 164, 994, 632, 890, 467,
#        856, 372,  98, 336,  92, 316, 800, 370, 474, 499, 423, 368, 496,
# ...

# %%
unique, counts = np.unique(values, return_counts=True)
dict(zip(unique, counts))
# Out:
# {1: 1,
#  7: 1,
#  15: 1,
#  23: 1,
#  29: 1,
#  32: 1,
#  36: 1,
#  41: 1,
#  50: 1,
#  54: 1,
#  56: 1,
#  60: 1,
#  61: 1,
#  65: 1,
#  74: 1,
#  75: 1,
#  83: 1,
#  84: 1,
#  87: 1,
#  92: 1,
#  93: 1,
#  96: 1,
#  98: 1,
#  107: 1,
#  113: 1,
#  115: 1,
#  126: 1,
#  132: 1,
#  155: 1,
#  159: 1,
#  161: 1,
#  164: 1,
#  178: 1,
#  180: 1,
#  182: 1,
#  186: 1,
#  197: 1,
#  200: 1,
#  201: 1,
#  205: 1,
#  208: 1,
#  209: 1,
#  212: 1,
#  214: 1,
#  224: 1,
#  227: 1,
#  233: 1,
#  239: 1,
#  242: 1,
#  243: 1,
#  245: 1,
#  248: 1,
#  250: 1,
#  253: 1,
#  260: 1,
#  262: 1,
#  268: 1,
#  273: 1,
#  277: 1,
#  278: 1,
#  281: 1,
#  286: 1,
#  291: 1,
#  292: 1,
#  297: 1,
#  299: 1,
#  303: 1,
#  311: 1,
#  315: 1,
#  316: 1,
#  325: 1,
#  327: 1,
#  330: 1,
#  336: 1,
#  340: 1,
#  341: 1,
#  347: 1,
#  363: 1,
#  367: 1,
#  368: 1,
#  369: 1,
#  370: 1,
#  371: 1,
#  372: 1,
#  381: 1,
#  388: 1,
#  398: 1,
#  404: 1,
#  406: 1,
#  409: 1,
#  413: 1,
#  417: 1,
#  423: 1,
# ...

# %%
len(values)
# Out:
# 200

# %%
df['Suspicious Activity']=False

# %%
df['No.of Transactions']=0
values=np.random.choice(range(10), 1000, replace=True)

# %%
len(values)
# Out:
# 1000

# %%
for i in range(1000):
         df.loc[i,'No.of Transactions']=values[i]

# %%
df.head()
# Out:
#   first_name last_name  gender  age        country       state  postal code  \
# 0    Barrett    Dybell    Male   73  United States    Colorado        80935
# 1     Correy   Antunez    Male   65  United States       Texas        76115
# 2      Robbi    Amsden  Female   24  United States     Florida        34611
# 3      Welby   Zanazzi    Male   61  United States       Texas        75353
# 4     Bailie    Keppel    Male   52  United States  New Mexico        88006
#
#   social security number   company                   job title  salary  \
# 0            655-91-9407  Fiveclub                     Actuary   49224
# 1            591-95-0381   Youfeed           Marketing Manager  122588
# 2            539-05-0912   Trilith                    Operator  100195
# 3            151-75-0158    Avamba               Developer III   53624
# 4            667-83-6790   Zoombox  Quality Control Specialist   29958
#
#           card number card type money_withdrawn_amount money_withdrawn_reason  \
# ...

# %%
df.drop(['Fradulent'],axis=1)
# Out:
#     first_name      last_name  gender  age        country  \
# 0      Barrett         Dybell    Male   73  United States
# 1       Correy        Antunez    Male   65  United States
# 2        Robbi         Amsden  Female   24  United States
# 3        Welby        Zanazzi    Male   61  United States
# 4       Bailie         Keppel    Male   52  United States
# 5     Fidelity          Axton  Female   87  United States
# 6      Aveline         Kelway  Female   34  United States
# 7        Rayna        Josephs  Female   45  United States
# 8       Myrtle       Denziloe  Female   75  United States
# 9    Krystalle      Congreave  Female   34  United States
# 10        Cull         Tabour    Male   20  United States
# 11      Carlos       Thurstan    Male   76  United States
# 12      Noelle       Sterrick  Female   55  United States
# 13      Maximo       Switland    Male   82  United States
# 14     Ethelyn     Malletratt  Female   41  United States
# ...

# %%
for k in range(1000):
      for i in values:
        if df.index[k]==i:
         df.loc[k,'Fraudulent']=0

# %%
df['Fradulent'].unique()
# Out:
# array([ True, False])

# %%
ct=0
for index, row in df.iterrows():
    if(row['Fradulent']==False):
         ct=ct+1
print(ct)
# Out:
# 200

# %%
for i in range(1000):
    df['money_withdrawn_amount'][i]=df['money_withdrawn_amount'][i][1:]
df['money_withdrawn_amount']=df['money_withdrawn_amount'].astype(float)
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# df.to_csv('NewData.csv', sep='\t', encoding='utf-8')

# %%
df['money_withdrawn_amount'].mean()
# Out:
# 15060.742890000023

# %%
ct=0
for i in range(1000):
    if(df['salary'][i]/12>df['money_withdrawn_amount'][i]):
     ct=ct+1
print(ct)
# Out:
# 237

# %%
df.to_excel("CustomerInfo2.xlsx")
