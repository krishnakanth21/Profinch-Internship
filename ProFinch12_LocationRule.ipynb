# %%
import pandas as pd
import numpy as np
import os
import pyodbc
import datetime

# %%
os.chdir('C:\\Users\\hp\\Desktop\\ProFinch')

# %%
df=pd.read_excel("CustomerInfo5.xlsx")

# %%
df=df.drop(['Unnamed: 0.1.1'],axis=1)

# %%
df.columns.tolist()
# Out:
# ['first_name',
#  'last_name',
#  'gender',
#  'age',
#  'country',
#  'state',
#  'postal code',
#  'social security number',
#  'company',
#  'job title',
#  'salary',
#  'card number',
#  'card type',
#  'money_withdrawn_amount',
#  'money_withdrawn_reason',
#  'money_withdrawn_location',
#  'Suspicious Activity',
#  'No.of Transactions',
#  'money_withdrawn_date',
#  'money_withdrawn_date_only',
#  'amount_transferred',
#  'sender_id',
#  'receiver_id',
#  'Time_only']

# %%
df[['state','money_withdrawn_location']]
# Out:
#               state money_withdrawn_location
# 0          Colorado                    Idaho
# 1             Texas                    Texas
# 2           Florida                 Illinois
# 3             Texas                    Texas
# 4        New Mexico               New Mexico
# ..              ...                      ...
# 995         Indiana                  Indiana
# 996         Arizona                  Arizona
# 997        New York                 New York
# 998  South Carolina           South Carolina
# 999    Pennsylvania                 Maryland
#
# [1000 rows x 2 columns]

# %%
list1=[]
list1=df['state'].unique()

# %%
for i in range(1000):
    df.loc[i,'money_withdrawn_location']=df['state'][i]

# %%
len(list1)
# Out:
# 46

# %%
import numpy as np
values=np.random.choice(range(1000), 200, replace=False)

# %%
values
# Out:
# array([695, 380, 880, 630, 384, 293, 740, 663, 285, 224, 143, 104, 320,
#        581,  28, 427, 999, 923, 202, 513, 595, 156, 764, 266, 212, 772,
#        672, 868, 733, 594, 474, 443, 312, 704, 253, 713, 515, 466, 170,
#        918, 174, 817, 750, 182, 166, 274, 783, 375, 108,   0, 667, 974,
#        229, 465, 871, 405, 300, 379, 280, 508, 970, 534, 814, 976, 489,
#        621, 550, 586, 745, 906, 457, 961, 562, 255, 761, 665, 415, 568,
#        929, 352, 705, 940, 281, 575,  14, 372, 912, 476, 747, 557, 990,
#         16, 506, 176, 147, 583, 932, 252, 200, 463, 597, 660, 883, 654,
#        121, 692, 282, 822, 643, 220, 315, 763,  25, 839, 346, 799, 902,
#        185, 676, 683, 579, 374, 301, 987, 762, 857, 725, 164, 388, 820,
#        100, 542, 509,  47, 217, 138, 158, 582, 585, 833, 845, 408, 326,
#         52, 359, 604,  75, 314, 439,  60, 729, 144, 743, 780, 852, 685,
#        666, 775,  73,  74, 788, 471, 870, 636, 410, 610, 177, 407, 864,
# ...

# %%
x=np.random.choice(range(46),1)
x[0]
# Out:
# 17

# %%
for i in range(1000):
    for j in range(200):
        if(df.index[i]==values[j]):
            x=np.random.choice(range(46),1)
            y=x[0]
            df.loc[i,'money_withdrawn_location']=list1[y]

# %%
ct=0
for i in range(1000):
    if(df['state'][i]!=df['money_withdrawn_location'][i]):
        ct=ct+1
print(ct)
# Out:
# 197

# %%
df
# Out:
#     first_name   last_name  gender  age        country           state  \
# 0      Barrett      Dybell    Male   73  United States        Colorado
# 1       Correy     Antunez    Male   65  United States           Texas
# 2        Robbi      Amsden  Female   24  United States         Florida
# 3        Welby     Zanazzi    Male   61  United States           Texas
# 4       Bailie      Keppel    Male   52  United States      New Mexico
# ..         ...         ...     ...  ...            ...             ...
# 995     Nickey     Danford    Male   55  United States         Indiana
# 996   Casandra         Old  Female   24  United States         Arizona
# 997      Kerby  Mablestone    Male   31  United States        New York
# 998      Griff       Thame    Male   60  United States  South Carolina
# 999     Rainer     Durante    Male   54  United States    Pennsylvania
#
#      postal code social security number        company  \
# 0          80935            655-91-9407       Fiveclub
# ...

# %%
df.to_excel("CustomerInfo5.xlsx")

# %% [markdown]
# # Testing the rule

# %%
import urllib
import sqlalchemy
conn_str = (
    r'Driver={SQL Server};'
    r'Server=DESKTOP-V8F09K2\KRISHNASQL;'
    r'Database=kk;'
    r'UID=sa;'
    r'PWD=pokemon;'
)
quoted_conn_str = urllib.parse.quote_plus(conn_str)
engine = sqlalchemy.create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted_conn_str))
cnxn = engine.connect()

# %%
rows = cnxn.execute("SELECT name FROM sys.tables").fetchall()
print(rows)
# Out:
# [('output',), ('output2',), ('fraud_names',), ('output3',)]

# %%
df.to_sql('output3', con=engine,if_exists='replace')

# %%
 and (([Time_only]>'01:00:01' and [Time_only]<'04:00:59'))
 ([state]!=[money_withdrawn_location]) and ([No.of Transactions]*([money_withdrawn_amount])>=([salary]))

# %%
conx = pyodbc.connect('DRIVER={SQL Server}; SERVER=DESKTOP-V8F09K2\KRISHNASQL; Database=kk; UID=sa; PWD=pokemon;')
query="select * from output3 where (([Time_only]>'01:00:01' and [Time_only]<'04:00:59')) or ([state]!=[money_withdrawn_location]) or (([money_withdrawn_amount])>=([salary]/2))"
cursor = conx.cursor();
cursor.execute(query);
data = cursor.fetchall()
q = pd.read_sql_query(query,conx)
df2 = pd.DataFrame(q, columns=df.columns)
conx.close()

# %%
len(data)
# Out:
# 346

# %%
df2
# Out:
#      Unnamed: 0 first_name  last_name  gender  age        country  \
# 0           NaN     Correy    Antunez    Male   65  United States
# 1           NaN      Welby    Zanazzi    Male   61  United States
# 2           NaN     Bailie     Keppel    Male   52  United States
# 3           NaN      Rayna    Josephs  Female   45  United States
# 4           NaN     Noelle   Sterrick  Female   55  United States
# ..          ...        ...        ...     ...  ...            ...
# 341         NaN     Angela      Aiken  Female   67  United States
# 342         NaN     Verena  Grimsdyke  Female   44  United States
# 343         NaN   Casandra        Old  Female   24  United States
# 344         NaN      Griff      Thame    Male   60  United States
# 345         NaN     Rainer    Durante    Male   54  United States
#
#               state  postal code social security number        company  ...  \
# 0             Texas        76115            591-95-0381        Youfeed  ...
# ...

# %% [markdown]
# # End of section
