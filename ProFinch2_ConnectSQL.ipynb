# %% [markdown]
# # Checking the connection with SQL Server

# %%
import pyodbc
import pandas as pd

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'SQL Server Native Client 11.0',
#  'SQL Server Native Client RDA 11.0',
#  'ODBC Driver 17 for SQL Server']

# %%
conx = pyodbc.connect('DRIVER={SQL Server}; SERVER=DESKTOP-V8F09K2\KRISHNASQL; Database=kk; UID=sa; PWD=pokemon;')

# %%
query = "SELECT * from output"

# %%
cursor = conx.cursor();

# %%
cursor.execute(query);

# %%
data = cursor.fetchall()

# %%
print(data[15])
# Out:
# (15.0, 'Anselm', 'Tonner', 'Male', 72.0, 'United States', 'Florida', 32505.0, '255-31-6815', 'Vitz', 'GIS Technical Architect', 27068.0, 5458640520374488.0, 'diners-club-us-ca', 20613.31, 'Health', 'Missouri', '11:47 PM', False, False, 5.0)

# %%
query = "SELECT first_name,last_name,gender from output where gender='Male'"
cursor = conx.cursor();
cursor.execute(query);
data = cursor.fetchall()

# %%
for row in data:
    print(row, end='\n')
# Out:
# (0.0, 'Barrett', 'Dybell', 'Male', 73.0, 'United States', 'Colorado', 80935.0, '655-91-9407', 'Fiveclub', 'Actuary', 49224.0, 3558725889734846.0, 'jcb', 6823.85, 'Electronics', 'California', '3:46 PM', True, False, 1.0)
# (1.0, 'Correy', 'Antunez', 'Male', 65.0, 'United States', 'Texas', 76115.0, '591-95-0381', 'Youfeed', 'Marketing Manager', 122588.0, 3531226201855205.0, 'jcb', 28609.13, 'Movies', 'New York', '6:56 AM', True, False, 3.0)
# (2.0, 'Robbi', 'Amsden', 'Female', 24.0, 'United States', 'Florida', 34611.0, '539-05-0912', 'Trilith', 'Operator', 100195.0, 3577207464865995.0, 'jcb', 11985.45, 'Sports', 'Kansas', '12:30 PM', True, False, 3.0)
# (3.0, 'Welby', 'Zanazzi', 'Male', 61.0, 'United States', 'Texas', 75353.0, '151-75-0158', 'Avamba', 'Developer III', 53624.0, 6.334013566582673e+17, 'solo', 1686.59, 'Tools', 'Kansas', '12:17 AM', True, False, 8.0)
# ...

# %%
q = pd.read_sql_query(query,conx)

# %%
df = pd.DataFrame(q, columns=['first_name','last_name','gender'])

# %%
df.head()
# Out:
#   first_name last_name gender
# 0    Barrett    Dybell   Male
# 1     Correy   Antunez   Male
# 2      Welby   Zanazzi   Male
# 3     Bailie    Keppel   Male
# 4       Cull    Tabour   Male

# %%
conx.close()
